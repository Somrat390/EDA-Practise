# %% [markdown]
# <a href="https://colab.research.google.com/github/Somrat390/EDA-Practise/blob/main/Line_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install radar
# Out:
# Collecting radar
#   Downloading radar-0.3.tar.gz (4.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: radar
#   Building wheel for radar (setup.py) ... done
#   Created wheel for radar: filename=radar-0.3-py3-none-any.whl size=4989 sha256=f42848b9efed959f5bf99e24923292a82db523c1e17b15c3225edd946d6b7231
#   Stored in directory: /root/.cache/pip/wheels/e8/67/aa/a63ff0c78f8e447ef451a9d033290153358237ce8bcdf6836b
# Successfully built radar
# Installing collected packages: radar
# Successfully installed radar-0.3

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.11.1-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.11.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 88.0 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.11.1

# %%
import datetime
import math
import pandas as pd
import random
import radar
from faker import Faker
fake = Faker()

# %%
def generateData(n):
  listdata = []
  start = datetime.datetime(2019,8,1)
  end = datetime.datetime(2019,8,30)

  delta = start - end

  for _ in range(n):
    date = radar.random_datetime(start='2019-08-1', stop='2019-08-30').strftime("%Y-%m-%d")
    price = round(random.uniform(900,1000),4)
    listdata.append([date,price])

  df = pd.DataFrame(listdata, columns=['Date','Price'])

  df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')

  df = df.groupby(by='Date').mean()

  return df

# %%
df = generateData(50)
df.head(10)
# Out:
#                  Price
# Date
# 2019-08-03  935.584400
# 2019-08-04  947.597300
# 2019-08-05  928.137150
# 2019-08-06  945.375900
# 2019-08-07  958.861967
# 2019-08-08  946.607067
# 2019-08-09  951.135200
# 2019-08-11  916.044033
# 2019-08-12  962.552950
# 2019-08-13  932.544200

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Now Ploting the Graph

# %%
plt.rcParams['figure.figsize'] = (14,10)
plt.plot(df)
